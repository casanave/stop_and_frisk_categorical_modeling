# %%
import pandas as pd

# %%
df_17 = pd.read_csv('raw_data/SF_2017.csv.gz')
df_17.head()
# Out:
#   STOP_FRISK_DATE_STOP_FRISK_TIME  STOP_FRISK_ID  YEAR2    MONTH2       DAY2  \
# 0      2017-01-16 14:25:59.999000  2017001010001   2017   January     Monday
# 1      2017-01-16 14:25:59.999000  2017001010002   2017   January     Monday
# 2      2017-02-08 11:09:59.999000  2017001010005   2017  February  Wednesday
# 3      2017-02-20 11:34:59.999000  2017001010006   2017  February     Monday
# 4             2017-02-21 13:20:00  2017001010007   2017  February    Tuesday
#
#         STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on Self Initiated                APP                  SGT
# 1  Based on Self Initiated                APP                  SGT
# 2    Based on C/W on Scene                APP                  POM
# 3  Based on Self Initiated                APP                  POM
# 4       Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE SUPERVISING_OFFICER_RANK  ...  \
# 0                           574                      SGT  ...
# 1                           574                      SGT  ...
# 2                           863                      SGT  ...
# 3                             1                      SGT  ...
# 4                             1                      SGT  ...
#
#    STOP_LOCATION_SECTOR_CODE STOP_LOCATION_APARTMENT  \
# 0                     (null)                  (null)
# 1                     (null)                  (null)
# 2                          C                  (null)
# 3                          H                  (null)
# 4                          H                       2
#
#   STOP_LOCATION_FULL_ADDRESS STOP_LOCATION_PREMISES_NAME  \
# 0       180 GREENWICH STREET                      (null)
# 1       180 GREENWICH STREET                      (null)
# 2    WALL STREET && BROADWAY                      (null)
# 3           75 GREENE STREET                      (null)
# 4          429 WEST BROADWAY                      (null)
#
#   STOP_LOCATION_STREET_NAME  STOP_LOCATION_X STOP_LOCATION_Y  \
# 0          GREENWICH STREET         982381.0        201750.0
# 1          GREENWICH STREET         982381.0        201750.0
# 2               WALL STREET         981005.0        197131.0
# 3             GREENE STREET         984031.0        202796.0
# 4             WEST BROADWAY         983894.0        203523.0
#
#    STOP_LOCATION_ZIP_CODE STOP_LOCATION_PATROL_BORO_NAME  \
# 0                  (null)                           PBMS
# 1                  (null)                           PBMS
# 2                  (null)                           PBMS
# 3                  (null)                           PBMS
# 4                  (null)                           PBMS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2               MANHATTAN
# 3               MANHATTAN
# 4               MANHATTAN
#
# [5 rows x 82 columns]

# %%
df_18 = pd.read_csv('raw_data/SF_2018.csv.gz')
df_18.head()
# Out:
#   STOP_FRISK_DATE_Stop Frisk Time  STOP_FRISK_ID  YEAR2   MONTH2    DAY2  \
# 0    2018-01-01 00:00:00 19:04:00              1   2018  January  Monday
# 1    2018-01-01 00:00:00 23:00:00              2   2018  January  Monday
# 2    2018-01-01 00:00:00 23:55:00              3   2018  January  Monday
# 3    2018-01-01 00:00:00 03:23:00              4   2018  January  Monday
# 4    2018-01-01 00:00:00 03:23:00              5   2018  January  Monday
#
#       STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on C/W on Scene                APP                  POM
# 1     Based on Radio Run                APP                  POM
# 2     Based on Radio Run                APP                  POM
# 3     Based on Radio Run                APP                  POM
# 4     Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE SUPERVISING_OFFICER_RANK  ...  \
# 0                             1                      SGT  ...
# 1                            34                      SGT  ...
# 2                           808                      SGT  ...
# 3                            63                      SGT  ...
# 4                            63                      SGT  ...
#
#    STOP_LOCATION_SECTOR_CODE STOP_LOCATION_APARTMENT  \
# 0                          G                  (null)
# 1                          C                  (null)
# 2                          B                      4M
# 3                          B                  (null)
# 4                          B                  (null)
#
#          STOP_LOCATION_FULL_ADDRESS STOP_LOCATION_PREMISES_NAME  \
# 0  VARICK STREET && FRANKLIN STREET                      (null)
# 1     DYCKMAN STREET && POST AVENUE                      (null)
# 2               2245 RANDALL AVENUE                      (null)
# 3        EAST 38 STREET && AVENUE L                      (null)
# 4        EAST 38 STREET && AVENUE L                      (null)
#
#   STOP_LOCATION_STREET_NAME  STOP_LOCATION_X STOP_LOCATION_Y  \
# 0             VARICK STREET           982327          201274
# 1            DYCKMAN STREET          1004892          253548
# 2            RANDALL AVENUE          1026706          237776
# 3            EAST 38 STREET          1001347          166195
# 4            EAST 38 STREET          1001347          166195
#
#    STOP_LOCATION_ZIP_CODE STOP_LOCATION_PATROL_BORO_NAME  \
# 0                  (null)                           PBMS
# 1                  (null)                           PBMN
# 2                  (null)                           PBBX
# 3                  (null)                           PBBS
# 4                  (null)                           PBBS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2                   BRONX
# 3                BROOKLYN
# 4                BROOKLYN
#
# [5 rows x 82 columns]

# %%
df_19 = pd.read_csv('raw_data/SF_2019.csv.gz')
df_19.head()
# Out:
#   STOP_FRISK_DATE_STOP_FRISK_TIME  STOP_ID_ANONY  YEAR2   MONTH2       DAY2  \
# 0             2019-01-02 14:30:00              1   2019  January  Wednesday
# 1             2019-01-08 02:30:00              2   2019  January    Tuesday
# 2             2019-01-12 16:54:00              3   2019  January   Saturday
# 3             2019-01-14 21:21:00              4   2019  January     Monday
# 4             2019-01-15 18:50:00              5   2019  January    Tuesday
#
#         STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0    Based on C/W on Scene                APP                  POM
# 1  Based on Self Initiated                APP                  POM
# 2       Based on Radio Run                APP                  POM
# 3       Based on Radio Run                APP                  POM
# 4       Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE SUPERVISING_OFFICER_RANK  ...  \
# 0                             1                      SGT  ...
# 1                             1                      SGT  ...
# 2                             1                      SGT  ...
# 3                             1                      SGT  ...
# 4                             1                      SGT  ...
#
#    STOP_LOCATION_PRECINCT STOP_LOCATION_SECTOR_CODE STOP_LOCATION_APARTMENT  \
# 0                       1                         C                  (null)
# 1                       1                         C                  (null)
# 2                       1                         D                  (null)
# 3                       1                         (                  (null)
# 4                       1                         D                  (null)
#
#   STOP_LOCATION_FULL_ADDRESS  STOP_LOCATION_STREET_NAME STOP_LOCATION_X  \
# 0           230 VESEY STREET               VESEY STREET          979667
# 1             9 WHITE STREET               WHITE STREET          982650
# 2          131 SPRING STREET              SPRING STREET          984063
# 3    GRAND STREET && 6TH AVE               GRAND STREET          982848
# 4         32 THOMPSON STREET            THOMPSON STREET          983100
#
#    STOP_LOCATION_Y STOP_LOCATION_ZIP_CODE STOP_LOCATION_PATROL_BORO_NAME  \
# 0           199737                 (null)                           PBMS
# 1           201326                 (null)                           PBMS
# 2           203033                 (null)                           PBMS
# 3           202677                 (null)                           PBMS
# 4           202705                 (null)                           PBMS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2               MANHATTAN
# 3               MANHATTAN
# 4               MANHATTAN
#
# [5 rows x 82 columns]

# %%
df_20 = pd.read_csv('raw_data/SF_2020.csv.gz')
df_20.head()
# Out:
#   STOP_FRISK_DATE_STOP_FRISK_TIME  STOP_ID  YEAR2   MONTH2       DAY2  \
# 0             2020-01-01 01:12:00        1   2020  January  Wednesday
# 1             2020-01-01 01:11:00        2   2020  January  Wednesday
# 2             2020-01-01 01:11:00        3   2020  January  Wednesday
# 3             2020-01-01 10:18:00        4   2020  January  Wednesday
# 4             2020-01-01 08:45:00        5   2020  January  Wednesday
#
#    STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on Radio Run                APP                  POM
# 1  Based on Radio Run                APP                  POM
# 2  Based on Radio Run                APP                  POM
# 3  Based on Radio Run                APP                  POM
# 4  Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE SUPERVISING_OFFICER_RANK  ...  \
# 0                            19                      SGT  ...
# 1                            19                      SGT  ...
# 2                            19                      SGT  ...
# 3                            75                       LT  ...
# 4                            78                      SGT  ...
#
#    STOP_LOCATION_PRECINCT STOP_LOCATION_SECTOR_CODE STOP_LOCATION_APARTMENT  \
# 0                      19                         C                  (null)
# 1                      19                         C                  (null)
# 2                      19                         C                  (null)
# 3                      75                         D                  (null)
# 4                      78                         B                  (null)
#
#     STOP_LOCATION_FULL_ADDRESS  STOP_LOCATION_STREET_NAME STOP_LOCATION_X  \
# 0                  248 E 83 ST                    E 83 ST          997094
# 1                  248 E 83 ST                    E 83 ST          997094
# 2                  248 E 83 ST                    E 83 ST          997094
# 3  LINDEN BLVD && SHEPHERD AVE                LINDEN BLVD         1018441
# 4                    481 5 AVE                      5 AVE          987763
#
#    STOP_LOCATION_Y STOP_LOCATION_ZIP_CODE STOP_LOCATION_PATROL_BORO_NAME  \
# 0           222002                  10028                           PBMN
# 1           222002                  10028                           PBMN
# 2           222002                  10028                           PBMN
# 3           181412                  11208                           PBBN
# 4           182543                  11215                           PBBS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2               MANHATTAN
# 3                BROOKLYN
# 4                BROOKLYN
#
# [5 rows x 82 columns]

# %%
df_21 = pd.read_csv('raw_data/SF_2021.csv.gz')
df_21.head()
# Out:
# /Users/b0ihazard/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   STOP_FRISK_DATE_STOP_FRISK_TIME  STOP_ID  YEAR2   MONTH2    DAY2  \
# 0             2021-01-01 01:50:00        1   2021  January  Friday
# 1             2021-01-01 10:55:00        2   2021  January  Friday
# 2             2021-01-01 10:10:00        3   2021  January  Friday
# 3             2021-01-01 20:17:00        4   2021  January  Friday
# 4             2021-01-01 19:59:00        5   2021  January  Friday
#
#       STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on C/W on Scene                APP                  SGT
# 1     Based on Radio Run                APP                  POM
# 2  Based on C/W on Scene                APP                  POM
# 3  Based on C/W on Scene                APP                  POM
# 4     Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE SUPERVISING_OFFICER_RANK  ...  \
# 0                            42                      POM  ...
# 1                           105                      SGT  ...
# 2                           106                      SGT  ...
# 3                            83                       LT  ...
# 4                            26                      SGT  ...
#
#   SUSPECT_OTHER_DESCRIPTION STOP_LOCATION_PRECINCT STOP_LOCATION_SECTOR_CODE  \
# 0                    (null)                     42                         B
# 1                       NaN                    105                         B
# 2            YELLOW SWEATER                    106                         A
# 3                    (null)                     73                         A
# 4                   UNKNOWN                     26                         C
#
#   STOP_LOCATION_APARTMENT STOP_LOCATION_FULL_ADDRESS  \
# 0                      2C            850 JENNINGS ST
# 1                  (null)          219 ST && 139 AVE
# 2                  (null)           151 AVE && 84 ST
# 3                  (null)  BROADWAY && MAC DOUGAL ST
# 4                      4D               439 W 125 ST
#
#    STOP_LOCATION_STREET_NAME STOP_LOCATION_X  STOP_LOCATION_Y  \
# 0                JENNINGS ST         1013737           242476
# 1                     219 ST         1052511           184460
# 2                    151 AVE         1025662           182632
# 3                   BROADWAY         1010122           187312
# 4                   W 125 ST          996623           235311
#
#   STOP_LOCATION_PATROL_BORO_NAME STOP_LOCATION_BORO_NAME
# 0                           PBBX                   BRONX
# 1                           PBQS                  QUEENS
# 2                           PBQS                  QUEENS
# 3                           PBBN                BROOKLYN
# 4                           PBMN               MANHATTAN
#
# [5 rows x 82 columns]
